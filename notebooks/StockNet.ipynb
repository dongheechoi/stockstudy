# %%
import sys
import pandas as pd
import os
sys.path.append('../')

# %%
data_dir = '../data/stocknet-dataset'

# %%
stock_table_df = pd.read_csv('{}/StockTable'.format(data_dir), delimiter='\t')
stock_table_df.head()
# Out:
#              Sector  Symbol                     Company
# 0  Basic Matierials    $XOM     Exxon Mobil Corporation
# 1  Basic Matierials  $RDS-B           Royal Dutch Shell
# 2  Basic Matierials    $PTR  PetroChina Company Limited
# 3  Basic Matierials    $CVX         Chevron Corporation
# 4  Basic Matierials    $TOT                  TOTAL S.A.

# %%
price_processed_folder = '{}/price/preprocessed'.format(data_dir)
for company_file in os.listdir(price_processed_folder):
    company_df = pd.read_csv('{}/{}'.format(price_processed_folder, company_file), delimiter='\t')
    print(company_df)
    break
# Out:
#       2017-09-01  0.001594  0.003851  0.009296  -0.000531  0.119995  \
# 0     2017-08-31  0.018669  0.002570  0.020022   0.000000  1.380005
# 1     2017-08-30  0.000406 -0.003654  0.003925  -0.004195  0.029999
# 2     2017-08-29  0.007774 -0.007365  0.007911  -0.007365  0.569999
# 3     2017-08-28  0.011589  0.002621  0.015039   0.001104  0.839997
# 4     2017-08-25  0.005131  0.001525  0.009291   0.001387  0.370002
# 5     2017-08-24  0.008249  0.002796  0.011046  -0.001678  0.590004
# 6     2017-08-23 -0.003206 -0.006411  0.002091  -0.006690 -0.230003
# 7     2017-08-22  0.014852  0.002970  0.016690   0.000849  1.050003
# 8     2017-08-21  0.010577 -0.000572  0.012436  -0.000715  0.739998
# 9     2017-08-18  0.001575 -0.004724  0.008447  -0.005440  0.110001
# 10    2017-08-17 -0.008094  0.002556  0.003692  -0.008378 -0.570000
# 11    2017-08-16  0.001137  0.002133  0.005829  -0.003270  0.080002
# 12    2017-08-15 -0.006778  0.003671  0.004518  -0.007625 -0.480004
# ...
